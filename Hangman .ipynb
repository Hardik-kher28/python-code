# %%
import random
a=['apple','orenge','banana','candy','burger','pizza','potato']
c= random.choice(a)
# print(c)
b=[]
gauss=[]
le=len(c)-1
i=random.randint(0,le)

for v1 in c:
    b.append(v1)
for v2 in c:
    gauss.append('_')
    
gauss[i] = b[i]
print(gauss)
    
# print(b)
attemp=0
game_over = False
while not game_over:
    if gauss != b:
        ent= input('enter gauss word  ')
        if ent in c:
            count = -1
            for var in c:
                count +=1
                if gauss[count] == '_':
                    if ent == var:
                        gauss[count]=ent
                        print(gauss)
                
        else:
            print('wrong gauss you are one step cloer to your death')
            attemp +=1
            print(gauss)
            print('___________')
            print('  |       |')
            print('  |       '+('0'if attemp > 0 else''))
            print('  |      '+('\\|/' if attemp > 1 else''))
            print('  |       '+('|' if attemp > 2 else''))
            print('  |      '+('/ \\' if attemp > 3 else''))
            print('  |          ')
            print('-------------')
            if attemp >=4:
                print('you are dead rest in peace')
                game_over = True
            
    else:
        print('you are winner')
        game_over = True
# Out:
# ['c', '_', '_', '_', '_']
# enter gauss word  k
# wrong gauss you are one step cloer to your death
# ['c', '_', '_', '_', '_']
# ___________
#   |       |
#   |       0
#   |
#   |
#   |
#   |
# -------------
# enter gauss word  k
# wrong gauss you are one step cloer to your death
# ['c', '_', '_', '_', '_']
# ___________
#   |       |
#   |       0
#   |      \|/
#   |
#   |
#   |
# -------------
# enter gauss word  k
# wrong gauss you are one step cloer to your death
# ['c', '_', '_', '_', '_']
# ___________
#   |       |
#   |       0
#   |      \|/
#   |       |
#   |
#   |
# -------------
# enter gauss word  k
# wrong gauss you are one step cloer to your death
# ['c', '_', '_', '_', '_']
# ___________
#   |       |
#   |       0
#   |      \|/
#   |       |
#   |      / \
#   |
# -------------
# you are dead rest in peace
